# %%
#Q1

print("Hello Python")
# Out:
# Hello Python

# %%
#Q2

a=6
b=2
print("a+b=",a+b)
print("a/b=",a//b)
# Out:
# a+b= 8
# a/b= 3

# %%
#Q3

base=8
height=3
print("Area of the triangle is ",0.5*base*height)
# Out:
# Area of the triangle is  12.0

# %%
#Q4

x = 5
y = 10

x, y = y, x
print("x =", x)
print("y =", y)
# Out:
# x = 10
# y = 5

# %%
#Q5

import random

print(random.randint(0,9))
# Out:
# 8

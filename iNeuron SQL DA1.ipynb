# %% [markdown]
# #Q1
#
# Select FIRST_NAME AS WORKER_NAME from Worker;

# %% [markdown]
# #Q2
#
# Select distinct DEPARTMENT from Worker;

# %% [markdown]
# #Q3
#
# SELECT * FROM
#
#                 (SELECT TOP 5 *
#
# FROM table_name
#
#                 ORDER BY ID DESC
#
#                 )
#
# ORDER BY id ASC;
